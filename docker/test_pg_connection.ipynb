# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

# %%
engine.connect()

# %%
query = """
    SELECT * 
    FROM pg_catalog.pg_tables
    WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema';
"""

query = """
    DROP TABLE IF EXISTS yellow_tripdata_trip;
"""

pd.read_sql(query, con=engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[27], line 11
#       1 query = """
#       2     SELECT *
#       3     FROM pg_catalog.pg_tables
#       4     WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema';
#       5 """
#       7 query = """
#       8     DROP TABLE IF EXISTS yellow_tripdata_trip;
#       9 """
# ---> 11 pd.read_sql(query, con=engine)
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:736, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     726     return pandas_sql.read_table(
#     727         sql,
#     728         index_col=index_col,
#    (...)
#     733         dtype_backend=dtype_backend,
#     734     )
#     735 else:
# --> 736     return pandas_sql.read_query(
#     737         sql,
#     738         index_col=index_col,
#     739         params=params,
#     740         coerce_float=coerce_float,
#     741         parse_dates=parse_dates,
#     742         chunksize=chunksize,
#     743         dtype_backend=dtype_backend,
#     744         dtype=dtype,
#     745     )
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:1849, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1802 """
#    1803 Read SQL query into a DataFrame.
#    1804
#    (...)
#    1846
#    1847 """
#    1848 result = self.execute(sql, params)
# -> 1849 columns = result.keys()
#    1851 if chunksize is not None:
#    1852     self.returns_generator = True
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\result.py:908, in _WithKeys.keys(self)
#     891 def keys(self) -> RMKeyView:
#     892     """Return an iterable view which yields the string keys that would
#     893     be represented by each :class:`_engine.Row`.
#     894
#    (...)
#     906
#     907     """
# --> 908     return self._metadata.keys
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\cursor.py:1374, in _NoResultMetaData.keys(self)
#    1372 @property
#    1373 def keys(self):
# -> 1374     self._we_dont_return_rows()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\cursor.py:1346, in _NoResultMetaData._we_dont_return_rows(self, err)
#    1345 def _we_dont_return_rows(self, err=None):
# -> 1346     raise exc.ResourceClosedError(
#    1347         "This result object does not return rows. "
#    1348         "It has been closed automatically."
#    1349     ) from err
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
df = pd.read_parquet("yellow_tripdata_2021-01.parquet")

# %%
df.head(5).to_sql(name="yellow_tripdata_trip", con=engine, index=False)
# Out:
# 5
